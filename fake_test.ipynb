# %%
from pointer_utils import *
# %matplotlib inline
# Out:
# load yolov3-tiny-pointer.cfg backup_YOLO/yolov3-tiny-pointer_5000.weights
# ['dial', 'pointer']

# %%
# %load_ext autoreload
# %autoreload 2

# %%
frame,classIds,confidences,boxes = preprocess(img_path = 'data_fake/20180413153457_none.jpg') # multiple box
# Out:
# load yolov3-tiny-pointer.cfg backup_YOLO/yolov3-tiny-pointer_5000.weights
# ['dial', 'pointer']

# %%
classIds,confidences,boxes = detect(frame)

# %%
plt.imshow(frame)

# %%
show_detection2??

# %%
show_detection2(frame, boxes)

# %%
frame,classIds,confidences,boxes = preprocess(img_path = 'data/20180413153457.jpg') # multiple box

# %%
show_detection2(frame, boxes)

# %%
frame,classIds,confidences,boxes = preprocess(img_path = 'data_fake/20180413153457_0.5.jpg') # multiple box

# %%
show_detection2(frame, boxes)

# %%
frame,classIds,confidences,boxes = preprocess(img_path = 'data_fake/20180413153457_0.7.jpg') # multiple box
show_detection2(frame, boxes)

# %%
frame,classIds,confidences,boxes = preprocess(img_path = 'data_fake/20180413153457_mult.jpg') # multiple box
show_detection2(frame, boxes)
